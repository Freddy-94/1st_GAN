# %% [markdown]
# <a href="https://colab.research.google.com/github/Freddy-94/1st_GAN/blob/main/Thesis_Project_GAN_Optimized_S%26P400_ST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Alfredo Bernal Luna
# ### December 21st 2024
# ### GAN implementation to forecast stock market prices (LSGAN version - S&P400 Index - Z-Score normalization over a window of 20 days - Same time for historic prices)
#
# In this project, we define a GAN architecture with a three-layer dense network as the generator, and a three-layer CNN as the discriminator.
#
# The **Generator** uses three fully connected (Dense) layers:
#
# 1.   First layer: The first dense layer with size generator_output_size * 10 followed by a ReLU activation.
# 2.   Second layer: The second dense layer with size generator_output_size * 5 also followed by ReLU 'generator_output_size'.
# 3. Third layer: The final dense layer outputs the reshaped data with dimensions (num_historical_days, num_features) to match the stock price time series data format.
#
# The **Discriminator** uses three convolutional layers:
#
# 1. Conv2D layers with 32, 64, and 128 filters, respectively, followed by ReLU activations.
# 2. Dropout layers are added for regularization during training.
# 3. A Flatten layer and two Dense layers, with the final Dense layer outputting a single value, which aligns with the Least Squares GAN (LSGAN) loss function.
#
# Our GAN model will generate synthetic features from stock price data, which will be then used as inputs for an XGBoost model to predict stock price movements. The XGBoost model is used to perform classification to predict whether stock prices will go up or down after a certain number of days (defined by the constant 'DAYS_AHEAD').
#
# The features for XGBoost are GAN-generated synthetic stock sequences flattened to 1D arrays, and the labels are computed based on the percent change in the stock's closing price over a given time horizon (in our case, 1 day ahead). If the percent change is greater than the threshold 'pct_change', the label is 1 (indicating an upward movement), otherwise, it is 0 (indicating a downward movement).
#
# The XGBoost model is trained to predict these labels, i.e., whether the stock price will go up or down based on the features generated by the GAN.
#
# **Data Flow and Preprocessing**:
#
# *   Training Data:
#   1.   The raw stock data is normalized using **Z-Score normalization** over a window of num_historical_days.
#   2.   We split the dataset into training and test sets. For training, the GAN generates synthetic sequences for the training set, which are used as inputs for XGBoost. The labels for training are derived from the actual stock price movements.
#
# *   Test Data:
#   1.  Similar to the training data, we use the GAN to generate synthetic stock data sequences for the test set. These synthetic sequences serve as input for the XGBoost model during evaluation.
#   2.   The test labels are derived from the real stock data’s price movements (percent change over 1 day).
#
# **XGBoost Training and Evaluation**:
#
# We train the XGBoost model with the GAN-generated features using a softmax objective for binary classification (i.e., whether the stock price will go up or down), and track performance using the mlogloss metric. Further, we perform early stopping based on the evaluation on the test set.
#
# After the training, the model's predictions on the test set are compared to the actual labels (up/down movements). We use a confusion matrix to evaluate the model’s accuracy, measuring how well the XGBoost model, trained on GAN-generated features, is able to predict stock price movements.
#
# **GAN-XGBoost Combination achievments**:
#
# The combination of GAN and XGBoost in this project serves two main purposes:
#
# 1.   **Synthetic Data Generation**: The GAN generates synthetic stock price data sequences that capture realistic market patterns, potentially providing better input features for prediction.
# 2.   **Stock Price Movement Prediction**: XGBoost uses these synthetic sequences to predict whether the stock price will rise or fall after a given time frame, based on the historical patterns captured by the GAN.

# %% [markdown]
# ### To mount your Google Drive to the Colab environment

# %%
# GOOGLE DRIVE - COLAB
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
# drive.mount('/content/drive')
drive.mount("/content/drive", force_remount=True)

# After executing the line above, Drive
# files will be present in "/content/drive/My Drive".
# !ls "/content/drive/My Drive"
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Global variables used in the project

# %%
# googlepath exists for googledrive finding the files.
# Have companylist.csv in same dir. Will create
# a stock_data folder and download stocks data into it.
googlepath = "drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/"

# Setting the Training Amount
TRAINING_AMOUNT = 50000 # 50000
SAVE_STEPS_AMOUNT = 10000 # testing for now
PCT_CHANGE_AMOUNT = 0.001 # just want to see up down trends ORIGINAL 5
HISTORICAL_DAYS_AMOUNT = 20
DAYS_AHEAD = 1 # ORIGINAL 5

# %% [markdown]
# ### Get data from Alpha Vantage

# %%
'''
Downloads stock data from alphavantage
'''
import pandas as pd
import os
import time
import urllib
import json
import csv
import requests
import io
from pathlib import Path
import random

ALPHA_VANTAGE_KEY = "HCG9KB9E1K095W5D"

'''
Saves data to a file
'''
def save(googlepath, stock_csv, output_dir, filename):
    try:
        output_path = os.path.join(googlepath, output_dir)
        if not os.path.exists(output_path):
            os.makedirs(output_path)

        filepath = os.path.join(output_path, filename)

        if not stock_csv.empty:
            if 'timestamp' in stock_csv.columns:
                stock_csv = stock_csv.sort_values(by='timestamp')
            stock_csv.to_csv(filepath, index=False)
            print(f"Saved data to {filepath}")
        else:
            print(f"DataFrame is empty for {filename}. Nothing to save.")
    except Exception as ex:
        print(f'Could not open file {filepath} to write data')
        print(ex)

def try_download(symbol):
    try:
        time.sleep(12)
        url = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={symbol}&apikey={ALPHA_VANTAGE_KEY}&datatype=csv&outputsize=full'
        c = pd.read_csv(url)
        if c.empty:
            raise ValueError(f"No data fetched for {symbol}")
        return c, True
    except Exception as ex:
        print(f"Error fetching data for {symbol}: {ex}")
        return None, None

#Given a stock symbol (aka 'goog') will download and save the data to the
#output dir as a csv

def download_symbol(symbol, output_dir, retry_count=4):
    stock_csv, didPass = try_download(symbol)
    if didPass:
        save(googlepath, stock_csv, output_dir, '{}.csv'.format(symbol))
    else:
        print('Failed to download {}'.format(symbol))


df = pd.read_csv(f"{googlepath}/companylist.csv")
for symbol in df.Symbol:
    my_file = Path(f"{googlepath}/stock_data/{symbol}.csv")  # check if already downloaded
    if not my_file.exists():
        print('Downloading {}'.format(symbol))
        download_symbol(symbol, 'stock_data')
    else:
        print(f"Already downloaded {symbol}")
# Out:
# Already downloaded AA
# Already downloaded AAL
# Already downloaded AAON
# Already downloaded ACHC
# Already downloaded ACM
# Already downloaded ADC
# Already downloaded AFG
# Already downloaded AGCO
# Already downloaded AIT
# Already downloaded ALE
# Already downloaded ALGM
# Already downloaded ALLY
# Already downloaded ALTM
# Already downloaded ALTR
# Already downloaded ALV
# Already downloaded AM
# Already downloaded AMED
# Already downloaded AMG
# Already downloaded AMH
# Already downloaded AMKR
# Already downloaded AN
# Already downloaded ANF
# Already downloaded APPF
# Already downloaded AR
# Already downloaded ARMK
# Already downloaded ARW
# Already downloaded ARWR
# Already downloaded ASB
# Already downloaded ASGN
# Already downloaded ASH
# Already downloaded ATR
# Already downloaded AVNT
# Already downloaded AVT
# Already downloaded AVTR
# Already downloaded AXTA
# Already downloaded AYI
# Already downloaded AZPN
# Already downloaded AZTA
# Already downloaded BC
# Already downloaded BCO
# Already downloaded BDC
# Already downloaded BERY
# Already downloaded BHF
# Already downloaded BIO
# Already downloaded BJ
# Already downloaded BKH
# Already downloaded BLD
# Already downloaded BLKB
# Already downloaded BMRN
# Already downloaded BRBR
# Already downloaded BRKR
# Already downloaded BRX
# Already downloaded BURL
# Already downloaded BWXT
# Already downloaded BYD
# Already downloaded CACI
# Already downloaded CADE
# Already downloaded CAR
# Already downloaded CASY
# Already downloaded CBSH
# Already downloaded CBT
# Already downloaded CC
# Already downloaded CCK
# Already downloaded CDP
# Already downloaded CELH
# Already downloaded CFR
# Already downloaded CG
# Already downloaded CGNX
# Already downloaded CHDN
# Already downloaded CHE
# Already downloaded CHH
# Already downloaded CHRD
# Already downloaded CHX
# Already downloaded CIEN
# Already downloaded CIVI
# Already downloaded CLF
# Already downloaded CLH
# Already downloaded CMC
# Already downloaded CNH
# Already downloaded CNM
# Already downloaded CNO
# Already downloaded CNX
# Already downloaded CNXC
# Already downloaded COHR
# Already downloaded COKE
# Already downloaded COLB
# Already downloaded COLM
# Already downloaded COTY
# Already downloaded CPRI
# Already downloaded CR
# Already downloaded CRI
# Already downloaded CROX
# Already downloaded CRUS
# Already downloaded CSL
# Already downloaded CUBE
# Already downloaded CUZ
# Already downloaded CVLT
# Already downloaded CW
# Already downloaded CXT
# Already downloaded CYTK
# Already downloaded DAR
# Already downloaded DBX
# Already downloaded DCI
# Already downloaded DINO
# Already downloaded DKS
# Already downloaded DLB
# Already downloaded DOCS
# Already downloaded DOCU
# Already downloaded DT
# Already downloaded DTM
# Already downloaded DUOL
# Already downloaded EEFT
# Already downloaded EGP
# Already downloaded EHC
# Already downloaded ELF
# Already downloaded ELS
# Already downloaded EME
# Already downloaded ENOV
# Already downloaded ENS
# Already downloaded ENSG
# Already downloaded EPR
# Already downloaded EQH
# Already downloaded ESAB
# Already downloaded ESNT
# Already downloaded EVR
# Already downloaded EWBC
# Already downloaded EXE
# Already downloaded EXEL
# Already downloaded EXLS
# Already downloaded EXP
# Already downloaded EXPO
# Already downloaded FAF
# Already downloaded FBIN
# Already downloaded FCFS
# Already downloaded FCN
# Already downloaded FFIN
# Already downloaded FHI
# Already downloaded FHN
# Already downloaded FIVE
# Already downloaded FIX
# Already downloaded FLO
# Already downloaded FLR
# Already downloaded FLS
# Already downloaded FN
# Already downloaded FNB
# Already downloaded FND
# Already downloaded FNF
# Already downloaded FR
# Already downloaded FYBR
# Already downloaded G
# Already downloaded GAP
# Already downloaded GATX
# Already downloaded GBCI
# Already downloaded GEF
# Already downloaded GGG
# Already downloaded GHC
# Already downloaded GLPI
# Already downloaded GME
# Already downloaded GMED
# Already downloaded GNTX
# Already downloaded GPK
# Already downloaded GT
# Already downloaded GTLS
# Already downloaded GXO
# Already downloaded H
# Already downloaded HAE
# Already downloaded HALO
# Already downloaded HGV
# Already downloaded HLI
# Already downloaded HLNE
# Already downloaded HOG
# Already downloaded HOMB
# Already downloaded HQY
# Already downloaded HR
# Already downloaded HRB
# Already downloaded HWC
# Already downloaded HXL
# Already downloaded IBKR
# Already downloaded IBOC
# Already downloaded IDA
# Already downloaded ILMN
# Already downloaded INGR
# Already downloaded IPGP
# Already downloaded IRDM
# Already downloaded IRT
# Already downloaded ITT
# Already downloaded JAZZ
# Already downloaded JEF
# Already downloaded JHG
# Already downloaded JLL
# Already downloaded JWN
# Already downloaded KBH
# Already downloaded KBR
# Already downloaded KD
# Already downloaded KEX
# Already downloaded KMPR
# Already downloaded KNF
# Already downloaded KNSL
# Already downloaded KNX
# Already downloaded KRC
# Already downloaded KRG
# Already downloaded LAD
# Already downloaded LAMR
# Already downloaded LANC
# Already downloaded LEA
# Already downloaded LECO
# Already downloaded LFUS
# Already downloaded LII
# Already downloaded LITE
# Already downloaded LIVN
# Already downloaded LNTH
# Already downloaded LNW
# Already downloaded LOPE
# Already downloaded LPX
# Already downloaded LSCC
# Already downloaded LSTR
# Already downloaded M
# Already downloaded MAN
# Already downloaded MANH
# Already downloaded MASI
# Already downloaded MAT
# Already downloaded MEDP
# Already downloaded MIDD
# Already downloaded MKSI
# Already downloaded MMS
# Already downloaded MORN
# Already downloaded MSA
# Already downloaded MSM
# Already downloaded MTDR
# Already downloaded MTG
# Already downloaded MTN
# Already downloaded MTSI
# Already downloaded MTZ
# Already downloaded MUR
# Already downloaded MUSA
# Already downloaded NBIX
# Already downloaded NEOG
# Already downloaded NEU
# Already downloaded NFG
# Already downloaded NJR
# Already downloaded NLY
# Already downloaded NNN
# Already downloaded NOV
# Already downloaded NOVT
# Already downloaded NSA
# Already downloaded NSP
# Already downloaded NVST
# Already downloaded NVT
# Already downloaded NWE
# Already downloaded NXST
# Already downloaded NXT
# Already downloaded FLG
# Already downloaded NYT
# Already downloaded OC
# Already downloaded OGE
# Already downloaded OGS
# Already downloaded OHI
# Already downloaded OLED
# Already downloaded OLLI
# Already downloaded OLN
# Already downloaded ONB
# Already downloaded ONTO
# Already downloaded OPCH
# Already downloaded ORA
# Already downloaded ORI
# Already downloaded OSK
# Already downloaded OVV
# Already downloaded OZK
# Already downloaded PAG
# Already downloaded PB
# Already downloaded PBF
# Already downloaded PCH
# Already downloaded PCTY
# Already downloaded PEN
# Already downloaded PFGC
# Already downloaded PII
# Already downloaded PK
# Already downloaded PLNT
# Already downloaded PNFP
# Already downloaded TXNM
# Already downloaded POR
# Already downloaded POST
# Already downloaded POWI
# Already downloaded PPC
# Already downloaded PR
# Already downloaded PRGO
# Already downloaded PRI
# Already downloaded PSN
# Already downloaded PSTG
# Already downloaded PVH
# Already downloaded QLYS
# Already downloaded R
# Already downloaded RBA
# Already downloaded RBC
# Already downloaded RCM
# Already downloaded REXR
# Already downloaded RGA
# Already downloaded RGEN
# Already downloaded RGLD
# Already downloaded RH
# Already downloaded RLI
# Already downloaded RMBS
# Already downloaded RNR
# Already downloaded ROIV
# Already downloaded RPM
# Already downloaded RRC
# Already downloaded RRX
# Already downloaded RS
# Already downloaded RYAN
# Already downloaded RYN
# Already downloaded SAIA
# Already downloaded SAIC
# Already downloaded SAM
# Already downloaded SBRA
# Already downloaded SCI
# Already downloaded SEIC
# Already downloaded SF
# Already downloaded SFM
# Already downloaded SHC
# Already downloaded SIGI
# Already downloaded SKX
# Already downloaded SLAB
# Already downloaded SLGN
# Already downloaded SLM
# Already downloaded SMG
# Already downloaded SNV
# Already downloaded SNX
# Already downloaded SON
# Already downloaded SR
# Already downloaded SRPT
# Already downloaded SSB
# Already downloaded SSD
# Already downloaded ST
# Already downloaded STAG
# Already downloaded STWD
# Already downloaded SWX
# Already downloaded SYNA
# Already downloaded TCBI
# Already downloaded TDC
# Already downloaded TEX
# Already downloaded THC
# Already downloaded THG
# Already downloaded THO
# Already downloaded TKO
# Already downloaded TKR
# Already downloaded TMHC
# Already downloaded TNL
# Already downloaded TOL
# Already downloaded TPL
# Already downloaded TPX
# Already downloaded TREX
# Already downloaded TTC
# Already downloaded TTEK
# Already downloaded TXRH
# Already downloaded UA
# Already downloaded UAA
# Already downloaded UBSI
# Already downloaded UFPI
# Already downloaded UGI
# Already downloaded UMBF
# Already downloaded UNM
# Already downloaded USFD
# Already downloaded UTHR
# Already downloaded VAC
# Already downloaded VAL
# Already downloaded VC
# Already downloaded VLY
# Already downloaded VMI
# Already downloaded VNO
# Already downloaded VNOM
# Already downloaded VNT
# Already downloaded VOYA
# Already downloaded VSH
# Already downloaded VVV
# Already downloaded WAL
# Already downloaded WBS
# Already downloaded WCC
# Already downloaded WEN
# Already downloaded WEX
# Already downloaded WFRD
# Already downloaded WH
# Already downloaded WHR
# Already downloaded WING
# Already downloaded WLK
# Already downloaded WMG
# Already downloaded WMS
# Already downloaded WPC
# Already downloaded WSM
# Already downloaded WSO
# Already downloaded WTFC
# Already downloaded WTRG
# Already downloaded WTS
# Already downloaded WU
# Already downloaded WWD
# Already downloaded X
# Already downloaded XPO
# Already downloaded XRAY
# Already downloaded YETI
# Already downloaded ZI
# Already downloaded ZION

# %% [markdown]
# ### Confusion Matrix plot definition

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix


def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    plt.ylim([1.5, -.5])


    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    #thresh = cm.max() / 2. # Previous
    fmt = '.4f' if normalize else 'd'
    thresh = cm.max() - 0.05

    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        #print (cm[i, j])
        plt.text(j, i, format(cm[i, j],fmt),
                 horizontalalignment="center",
                 fontsize=24,
                 color="white" if cm[i, j] > thresh else "black")

    #for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    #    plt.text(j, i, cm[i, j],
    #             horizontalalignment="center",
    #             color="black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %% [markdown]
# ### Initializing the GAN definition

# %%
import tensorflow as tf
import numpy as np

class GAN(tf.keras.Model):
    def __init__(self, num_features, num_historical_days, generator_input_size=200, is_train=True):
        super(GAN, self).__init__()
        self.num_features = num_features
        self.num_historical_days = num_historical_days
        self.generator_input_size = generator_input_size
        self.is_train = is_train

        # Build generator and discriminator
        self.generator = self.build_generator()
        self.discriminator = self.build_discriminator()

    def sample_Z(self, batch_size, n):
        return np.random.uniform(-1., 1., size=(batch_size, n))

    def build_generator(self):
        model = tf.keras.Sequential()
        generator_output_size = self.num_features * self.num_historical_days

        model.add(tf.keras.layers.Dense(generator_output_size * 10, input_dim=self.generator_input_size))
        model.add(tf.keras.layers.Activation('relu'))

        model.add(tf.keras.layers.Dense(generator_output_size * 5))
        model.add(tf.keras.layers.Activation('relu'))

        model.add(tf.keras.layers.Dense(generator_output_size))
        model.add(tf.keras.layers.Reshape((self.num_historical_days, self.num_features)))

        return model

    def build_discriminator(self):
        model = tf.keras.Sequential()

        model.add(tf.keras.layers.Conv2D(32, (3, 1), input_shape=(self.num_historical_days, 1, self.num_features), padding='same'))
        model.add(tf.keras.layers.ReLU())
        if self.is_train:
            model.add(tf.keras.layers.Dropout(0.3))

        model.add(tf.keras.layers.Conv2D(64, (3, 1), padding='same'))
        model.add(tf.keras.layers.ReLU())
        if self.is_train:
            model.add(tf.keras.layers.Dropout(0.3))

        model.add(tf.keras.layers.Conv2D(128, (3, 1), padding='valid'))
        model.add(tf.keras.layers.ReLU())
        if self.is_train:
            model.add(tf.keras.layers.Dropout(0.3))

        model.add(tf.keras.layers.Flatten())
        model.add(tf.keras.layers.Dense(128))
        model.add(tf.keras.layers.ReLU())
        model.add(tf.keras.layers.Dense(1)) # LSGAN

        return model

    def call(self, inputs, training=False):
        noise, real_data = inputs
        generated_data = self.generator(noise, training=training)
        generated_data = tf.reshape(generated_data, [-1, self.num_historical_days, 1, self.num_features])
        real_data = tf.reshape(real_data, [-1, self.num_historical_days, 1, self.num_features])

        real_output = self.discriminator(real_data, training=training)
        fake_output = self.discriminator(generated_data, training=training)

        return real_output, fake_output, generated_data

    def discriminator_loss(self, real_output, fake_output):
        real_loss = tf.reduce_mean((real_output - 1) ** 2)
        fake_loss = tf.reduce_mean(fake_output ** 2)
        return real_loss + fake_loss

    def generator_loss(self, fake_output):
        return tf.reduce_mean((fake_output - 1) ** 2)

# %% [markdown]
# ### Tensorflow version

# %%
print("TensorFlow version: {}".format(tf.__version__))
print("Eager execution is: {}".format(tf.executing_eagerly()))
# Out:
# TensorFlow version: 2.17.1
# Eager execution is: True

# %% [markdown]
# ### Training the GAN

# %%
import tensorflow as tf
import numpy as np
import random
import os
import pandas as pd
import matplotlib.pyplot as plt

random.seed(24)

class TrainGan:
    def __init__(self, num_historical_days, batch_size=128):
        self.batch_size = batch_size
        self.data = []

        files = [f"{googlepath}stock_data/{f}" for f in os.listdir(f"{googlepath}stock_data")]

        for file in files:
            print(file)
            df = pd.read_csv(file, index_col='timestamp', parse_dates=True)
            df = df[['open', 'high', 'low', 'close', 'volume']]

            df = (df - df.rolling(num_historical_days).mean().shift(-num_historical_days)) / df.rolling(num_historical_days).std().shift(-num_historical_days)

            df = df.dropna()
            df = df[400:]

            for i in range(num_historical_days, len(df), num_historical_days):
                self.data.append(df.values[i-num_historical_days:i])

        self.gan = GAN(num_features=5, num_historical_days=num_historical_days,
                       generator_input_size=200)

        # Optimizers
        self.G_optimizer = tf.keras.optimizers.Adam(learning_rate=0.000055)
        self.D_optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

        # Initialize lists for loss tracking
        self.g_loss_array = []
        self.d_loss_array = []

    def random_batch(self, batch_size=128):
        batch = []
        while True:
            batch.append(random.choice(self.data))
            if len(batch) == batch_size:
                yield batch
                batch = []

    def train(self, print_steps=100, display_data=100, save_steps=1000):
        if not os.path.exists(f'{googlepath}models'):
            os.makedirs(f'{googlepath}models')

        current_step = 0

        for i, X in enumerate(self.random_batch(self.batch_size)):
            noise = self.gan.sample_Z(self.batch_size, 200)

            with tf.GradientTape() as tape:
                D_real, D_fake, _ = self.gan((noise, X), training=True)
                D_loss = self.gan.discriminator_loss(D_real, D_fake) # LSGAN

            grads = tape.gradient(D_loss, self.gan.discriminator.trainable_variables)
            self.D_optimizer.apply_gradients(zip(grads, self.gan.discriminator.trainable_variables))

            with tf.GradientTape() as tape:
                _, D_fake, _ = self.gan((noise, X), training=True)
                G_loss = self.gan.generator_loss(D_fake) # LSGAN

            grads = tape.gradient(G_loss, self.gan.generator.trainable_variables)
            self.G_optimizer.apply_gradients(zip(grads, self.gan.generator.trainable_variables))

            # Record losses
            self.g_loss_array.append(G_loss.numpy())
            self.d_loss_array.append(D_loss.numpy())

            if (i + 1) % print_steps == 0:
                print(f'Step={i + current_step} D_loss={D_loss.numpy()} G_loss={G_loss.numpy()}')

            if (i + 1) % save_steps == 0:
                self.gan.save_weights(f'{googlepath}/models/gan.weights.h5')

            if ((i + current_step) > TRAINING_AMOUNT):
                print(f"Reached {i + current_step} epochs for GAN")
                break

        # Plot the losses
        self.plot_losses()

    def plot_losses(self):
        plt.figure(figsize=(12, 6))

        # Plot generator loss
        plt.subplot(1, 2, 1)
        plt.plot(self.g_loss_array, label='Generator Loss')
        plt.title('Generator Loss')
        plt.xlabel('Steps')
        plt.ylabel('Loss')
        plt.legend()

        # Plot discriminator loss
        plt.subplot(1, 2, 2)
        plt.plot(self.d_loss_array, label='Discriminator Loss')
        plt.title('Discriminator Loss')
        plt.xlabel('Steps')
        plt.ylabel('Loss')
        plt.legend()

        plt.tight_layout()
        plt.show()

gan = TrainGan(HISTORICAL_DAYS_AMOUNT, 128)
gan.train()
# Out:
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AAL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AAON.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ACHC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ACM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ADC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AFG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AGCO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AIT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ALE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ALGM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ALLY.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ALTM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ALTR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ALV.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AMED.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AMG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AMH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AMKR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ANF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/APPF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ARMK.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ARW.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ARWR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ASB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ASGN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ASH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ATR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AVNT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AVT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AVTR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AXTA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AYI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AZPN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AZTA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BCO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BDC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BERY.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BHF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BIO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BJ.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BKH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BLD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BLKB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BMRN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BRBR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BRKR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BRX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BURL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BWXT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BYD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CACI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CADE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CAR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CASY.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CBSH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CBT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CCK.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CDP.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CELH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CFR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CGNX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CHDN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CHE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CHH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CHRD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CHX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CIEN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CIVI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CLF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CLH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CMC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CNH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CNM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CNO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CNX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CNXC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/COHR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/COKE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/COLB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/COLM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/COTY.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CPRI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CRI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CROX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CRUS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CSL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CUBE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CUZ.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CVLT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CW.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CXT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CYTK.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/DAR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/DBX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/DCI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/DINO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/DKS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/DLB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/DOCS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/DOCU.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/DT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/DTM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/DUOL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/EEFT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/EGP.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/EHC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ELF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ELS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/EME.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ENOV.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ENS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ENSG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/EPR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/EQH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ESAB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ESNT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/EVR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/EWBC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/EXE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/EXEL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/EXLS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/EXP.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/EXPO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FAF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FBIN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FCFS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FCN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FFIN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FHI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FHN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FIVE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FIX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FLG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FLO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FLR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FLS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FNB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FND.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FNF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FYBR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/G.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GAP.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GATX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GBCI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GEF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GGG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GHC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GLPI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GME.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GMED.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GNTX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GPK.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GTLS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GXO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/H.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/HAE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/HALO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/HGV.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/HLI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/HLNE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/HOG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/HOMB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/HQY.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/HR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/HRB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/HWC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/HXL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/IBKR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/IBOC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/IDA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ILMN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/INGR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/IPGP.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/IRDM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/IRT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ITT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/JAZZ.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/JEF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/JHG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/JLL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/JWN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/KBH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/KBR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/KD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/KEX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/KMPR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/KNF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/KNSL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/KNX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/KRC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/KRG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LAD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LAMR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LANC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LEA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LECO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LFUS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LII.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LITE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LIVN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LNTH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LNW.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LOPE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LPX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LSCC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LSTR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/M.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MAN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MANH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MASI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MAT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MEDP.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MIDD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MKSI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MMS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MORN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MSA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MSM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MTDR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MTG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MTN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MTSI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MTZ.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MUR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MUSA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NBIX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NEOG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NEU.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NFG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NJR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NLY.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NNN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NOV.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NOVT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NSA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NSP.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NVST.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NVT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NWE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NXST.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NXT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NYT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/OC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/OGE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/OGS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/OHI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/OLED.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/OLLI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/OLN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ONB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ONTO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/OPCH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ORA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ORI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/OSK.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/OVV.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/OZK.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PAG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PBF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PCH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PCTY.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PEN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PFGC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PII.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PK.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PLNT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PNFP.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/POR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/POST.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/POWI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PPC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PRGO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PRI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PSN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PSTG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PVH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/QLYS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/R.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RBA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RBC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RCM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/REXR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RGA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RGEN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RGLD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RLI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RMBS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RNR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ROIV.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RPM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RRC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RRX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RYAN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RYN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SAIA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SAIC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SAM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SBRA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SCI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SEIC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SFM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SHC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SIGI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SKX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SLAB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SLGN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SLM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SMG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SNV.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SNX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SON.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SRPT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SSB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SSD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ST.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/STAG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/STWD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SWX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SYNA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TCBI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TDC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TEX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/THC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/THG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/THO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TKO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TKR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TMHC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TNL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TOL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TPL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TPX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TREX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TTC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TTEK.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TXNM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TXRH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/UA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/UAA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/UBSI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/UFPI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/UGI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/UMBF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/UNM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/USFD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/UTHR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/VAC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/VAL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/VC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/VLY.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/VMI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/VNO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/VNOM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/VNT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/VOYA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/VSH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/VVV.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WAL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WBS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WCC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WEN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WEX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WFRD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WHR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WING.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WLK.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WMG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WMS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WPC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WSM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WSO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WTFC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WTRG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WTS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WU.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WWD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/X.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/XPO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/XRAY.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/YETI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ZI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ZION.csv
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#


        # Load and preprocess stock data
        files = [os.path.join(f'{googlepath}stock_data', f) for f in os.listdir(f'{googlepath}/stock_data')]
        for file in files:
            print(file)
            df = pd.read_csv(file, index_col='timestamp', parse_dates=True)
            df = df[['open', 'high', 'low', 'close', 'volume']]

            # Compute labels
            labels = df.close.pct_change(days).map(lambda x: int(x > pct_change / 100.0))
            # Check class distribution    NEW LINE
            label_counts = labels.value_counts()  # Check class distribution
            print(f"Class distribution: \n{label_counts}")

            # Calculate scale_pos_weight
            #scale_pos_weight = label_counts[0] / label_counts[1]

            df = (df - df.rolling(num_historical_days).mean().shift(-num_historical_days)) / df.rolling(num_historical_days).std().shift(-num_historical_days)
            df['labels'] = labels
            df = df.dropna()

            # Split into training and testing data
            test_df = df[:365]
            df = df[400:]

            data = df[['open', 'high', 'low', 'close', 'volume']].values
            labels = df['labels'].values

            noise_dim = 200
            for i in range(num_historical_days, len(df), num_historical_days):
                noise = tf.random.normal([1, noise_dim])
                features = self.gan.generator.predict(noise)

                # Flatten the features to 1D array
                self.data.append(features[0].flatten())
                self.labels.append(labels[i-1])

            data = test_df[['open', 'high', 'low', 'close', 'volume']].values
            labels = test_df['labels'].values
            for i in range(num_historical_days, len(test_df), 1):
                noise = tf.random.normal([1, noise_dim])
                features = self.gan.generator.predict(noise)

                # Flatten the features to 1D array
                self.test_data.append(features[0].flatten())
                self.test_labels.append(labels[i-1])

        # Store the scale_pos_weight for later use
        #self.scale_pos_weight = scale_pos_weight

    def train(self):
        # XGBoost parameters including the scale_pos_weight
        params = {
            'objective': 'multi:softprob',
            'eta': 0.01, # 0.01
            'num_class': 2,
            'max_depth': 20, #20
            'subsample': 0.05, # 0.05
            'colsample_bytree': 0.05, # 0.05
            'eval_metric': 'mlogloss'#,
            #'scale_pos_weight': 3,  # Add the calculated scale_pos_weight
            #'alpha': 0.5,  # L1 regularization
            #'lambda': 2.0  # L2 regularization
        }

        # Convert lists to numpy arrays for xgboost DMatrix
        train_data = xgb.DMatrix(np.array(self.data), label=np.array(self.labels))
        test_data = xgb.DMatrix(np.array(self.test_data), label=np.array(self.test_labels))

        watchlist = [(train_data, 'train'), (test_data, 'test')]
        clf = xgb.train(params, train_data, 1000, evals=watchlist, early_stopping_rounds=100)

        # Save the model
        dump(clf, f'{googlepath}models/clf.pkl')

        # Predict and compute confusion matrix
        predictions = clf.predict(test_data)
        cm = confusion_matrix(self.test_labels, list(map(lambda x: int(x[1] > .5), predictions)))
        print(cm)

        # Plot confusion matrix if necessary
        plot_confusion_matrix(cm, ['Down', 'Up'], normalize=True, title="Confusion Matrix")

        # Feature importance
        importance = clf.get_score(importance_type='weight')
        importance = sorted(importance.items(), key=lambda x: x[1], reverse=True)
        print("Feature importance (by weight):", importance)

        # Plot feature importance
        xgb.plot_importance(clf)
        plt.show()

# Example usage:
boost_model = TrainXGBBoost(num_historical_days=HISTORICAL_DAYS_AMOUNT, days=DAYS_AHEAD, pct_change=PCT_CHANGE_AMOUNT)
boost_model.train()
# Out:
# No checkpoint found at drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/models/checkpoint. Proceeding without it.
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AA.csv
# Class distribution:
# close
# 1    106
# 0    101
# Name: count, dtype: int64
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py:258: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AAL.csv
# Class distribution:
# close
# 0    109
# 1     98
# Name: count, dtype: int64
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py:258: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AAON.csv
# Class distribution:
# close
# 1    122
# 0     85
# Name: count, dtype: int64
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py:258: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ACHC.csv
# Class distribution:
# close
# 0    110
# 1     97
# Name: count, dtype: int64
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py:258: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ACM.csv
# Class distribution:
# close
# 1    113
# 0     94
# Name: count, dtype: int64
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py:258: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ADC.csv
# Class distribution:
# close
# 1    110
# 0     97
# Name: count, dtype: int64
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py:258: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AFG.csv
# Class distribution:
# close
# 1    112
# 0     95
# Name: count, dtype: int64
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py:258: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# ...
# Class distribution:
# close
# 1    114
# 0     93
# Name: count, dtype: int64
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py:258: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# [0]	train-mlogloss:0.69253	test-mlogloss:0.69325
# [1]	train-mlogloss:0.69200	test-mlogloss:0.69333
# [2]	train-mlogloss:0.69196	test-mlogloss:0.69322
# [3]	train-mlogloss:0.69115	test-mlogloss:0.69342
# [4]	train-mlogloss:0.69153	test-mlogloss:0.69331
# [5]	train-mlogloss:0.69146	test-mlogloss:0.69325
# [6]	train-mlogloss:0.69087	test-mlogloss:0.69333
# [7]	train-mlogloss:0.69061	test-mlogloss:0.69333
# [8]	train-mlogloss:0.69136	test-mlogloss:0.69321
# [9]	train-mlogloss:0.69155	test-mlogloss:0.69326
# [10]	train-mlogloss:0.69151	test-mlogloss:0.69324
# [112]	train-mlogloss:0.67915	test-mlogloss:0.69289
# [113]	train-mlogloss:0.67873	test-mlogloss:0.69290
# [114]	train-mlogloss:0.67838	test-mlogloss:0.69293
# [115]	train-mlogloss:0.67810	test-mlogloss:0.69295
# [116]	train-mlogloss:0.67807	test-mlogloss:0.69297
# [117]	train-mlogloss:0.67747	test-mlogloss:0.69301
# [118]	train-mlogloss:0.67713	test-mlogloss:0.69306
# [119]	train-mlogloss:0.67673	test-mlogloss:0.69310
# [120]	train-mlogloss:0.67590	test-mlogloss:0.69315
# [121]	train-mlogloss:0.67615	test-mlogloss:0.69311
# [122]	train-mlogloss:0.67549	test-mlogloss:0.69316
# [123]	train-mlogloss:0.67521	test-mlogloss:0.69324
# [124]	train-mlogloss:0.67456	test-mlogloss:0.69329
# [125]	train-mlogloss:0.67433	test-mlogloss:0.69332
# [126]	train-mlogloss:0.67380	test-mlogloss:0.69343
# [127]	train-mlogloss:0.67320	test-mlogloss:0.69345
# [128]	train-mlogloss:0.67339	test-mlogloss:0.69342
# [129]	train-mlogloss:0.67295	test-mlogloss:0.69352
# [130]	train-mlogloss:0.67282	test-mlogloss:0.69353
# [131]	train-mlogloss:0.67319	test-mlogloss:0.69346
# [132]	train-mlogloss:0.67322	test-mlogloss:0.69342
# [133]	train-mlogloss:0.67320	test-mlogloss:0.69348
# [134]	train-mlogloss:0.67292	test-mlogloss:0.69349
# [135]	train-mlogloss:0.67315	test-mlogloss:0.69341
# [136]	train-mlogloss:0.67301	test-mlogloss:0.69347
# [137]	train-mlogloss:0.67316	test-mlogloss:0.69344
# [138]	train-mlogloss:0.67333	test-mlogloss:0.69337
# [139]	train-mlogloss:0.67321	test-mlogloss:0.69334
# [140]	train-mlogloss:0.67330	test-mlogloss:0.69328
# [141]	train-mlogloss:0.67295	test-mlogloss:0.69328
# [142]	train-mlogloss:0.67283	test-mlogloss:0.69335
# [143]	train-mlogloss:0.67226	test-mlogloss:0.69346
# [144]	train-mlogloss:0.67193	test-mlogloss:0.69353
# [145]	train-mlogloss:0.67198	test-mlogloss:0.69349
# [146]	train-mlogloss:0.67194	test-mlogloss:0.69345
# [147]	train-mlogloss:0.67168	test-mlogloss:0.69342
# [148]	train-mlogloss:0.67132	test-mlogloss:0.69347
# [149]	train-mlogloss:0.67111	test-mlogloss:0.69349
# [150]	train-mlogloss:0.67086	test-mlogloss:0.69359
# [151]	train-mlogloss:0.67056	test-mlogloss:0.69360
# [152]	train-mlogloss:0.67069	test-mlogloss:0.69356
# [[14877 17494]
#  [15831 18975]]
# Normalized confusion matrix
# [[0.45957802 0.54042198]
#  [0.45483537 0.54516463]]
# Feature importance (by weight): [('f91', 7.0), ('f35', 6.0), ('f86', 6.0), ('f6', 5.0), ('f14', 5.0), ('f34', 5.0), ('f41', 5.0), ('f51', 5.0), ('f55', 5.0), ('f60', 5.0), ('f71', 5.0), ('f84', 5.0), ('f3', 4.0), ('f9', 4.0), ('f20', 4.0), ('f22', 4.0), ('f23', 4.0), ('f30', 4.0), ('f32', 4.0), ('f40', 4.0), ('f56', 4.0), ('f57', 4.0), ('f58', 4.0), ('f64', 4.0), ('f65', 4.0), ('f70', 4.0), ('f73', 4.0), ('f79', 4.0), ('f87', 4.0), ('f0', 3.0), ('f1', 3.0), ('f4', 3.0), ('f7', 3.0), ('f10', 3.0), ('f11', 3.0), ('f16', 3.0), ('f27', 3.0), ('f28', 3.0), ('f36', 3.0), ('f42', 3.0), ('f43', 3.0), ('f44', 3.0), ('f48', 3.0), ('f49', 3.0), ('f54', 3.0), ('f62', 3.0), ('f72', 3.0), ('f90', 3.0), ('f92', 3.0), ('f97', 3.0), ('f98', 3.0), ('f8', 2.0), ('f13', 2.0), ('f15', 2.0), ('f17', 2.0), ('f18', 2.0), ('f19', 2.0), ('f21', 2.0), ('f29', 2.0), ('f33', 2.0), ('f37', 2.0), ('f39', 2.0), ('f47', 2.0), ('f63', 2.0), ('f68', 2.0), ('f69', 2.0), ('f75', 2.0), ('f76', 2.0), ('f77', 2.0), ('f80', 2.0), ('f81', 2.0), ('f82', 2.0), ('f83', 2.0), ('f93', 2.0), ('f94', 2.0), ('f95', 2.0), ('f5', 1.0), ('f12', 1.0), ('f24', 1.0), ('f25', 1.0), ('f26', 1.0), ('f31', 1.0), ('f38', 1.0), ('f45', 1.0), ('f52', 1.0), ('f53', 1.0), ('f59', 1.0), ('f66', 1.0), ('f67', 1.0), ('f78', 1.0), ('f85', 1.0), ('f89', 1.0), ('f96', 1.0), ('f99', 1.0)]

# %%
import os

# Below Code Gets Rid of Copy Of when making a copy of the models.
for filename in os.listdir(f'{googlepath}models/'):
    split = filename.split(" ")
    if len(split) == 2:
        os.rename(f'{googlepath}models/{filename}', f'{googlepath}models/{split[1]}')
    else:
        print("Nothing to rename.")

# Below Code Gets Rid of Checkpoint Number in Name
for filename in os.listdir(f'{googlepath}models/'):
    split = filename.split(".")
    if len(split) == 3:
        prefix, _, suffix = split
        new_name = prefix + "." + suffix
        os.rename(f'{googlepath}models/{filename}', f'{googlepath}models/{new_name}')
    elif filename == "clf.pkl":
        os.rename(f'{googlepath}models/{filename}', f'{googlepath}models/xgb')
    else:
        print("Nothing to rename.")
# Out:
# Nothing to rename.
# Nothing to rename.
# Nothing to rename.

# %% [markdown]
# ### Get the Predictions

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import joblib
import xgboost as xgb

tf.config.run_functions_eagerly(True)  # Enable eager execution

class Predict:
    def __init__(self, num_historical_days=20, days=10, pct_change=0,
                 gan_weights_path=f'{googlepath}models/gan.h5',
                 xgb_model_path=f'{googlepath}models/xgb'):
        self.num_historical_days = num_historical_days
        self.gan_weights_path = gan_weights_path
        self.xgb_model_path = xgb_model_path
        self.data = []

        # Check if the model files exist
        for model_path in [self.gan_weights_path, self.xgb_model_path]:
            if not os.path.exists(model_path):
                raise FileNotFoundError(f"No file found at {model_path}")

        # Load and preprocess stock data
        files = [os.path.join(f'{googlepath}stock_data', f) for f in os.listdir(f'{googlepath}stock_data')]
        for file in files:
            print(file)
            df = pd.read_csv(file, index_col='timestamp', parse_dates=True)
            df = df.sort_index(ascending=False)
            df = df[['open', 'high', 'low', 'close', 'volume']]
            df = (df - df.rolling(num_historical_days).mean().shift(-num_historical_days)) / df.rolling(num_historical_days).std().shift(-num_historical_days)
            df = df.dropna()
            if len(df) >= self.num_historical_days + 200:
                self.data.append((file.split('/')[-1], df.index[0], df[200:200 + self.num_historical_days].values))

    def build_gan_model(self):
        """Rebuild the GAN model architecture."""
        model = GAN(num_features=5, num_historical_days=self.num_historical_days,
                    generator_input_size=200, is_train=False)
        return model

    def load_gan_model(self):
        """Load the GAN model and its weights."""
        gan = self.build_gan_model()
        try:
            # Initialize model to create the graph
            dummy_noise = tf.random.normal([1, 200])  # Adjust shape based on GAN architecture
            dummy_data = tf.random.normal([1, self.num_historical_days, 5])  # Adjust shape based on GAN architecture
            _ = gan((dummy_noise, dummy_data), training=False)  # Ensure the model is built and variables are created

            # Load weights now that the model is initialized
            gan.load_weights(self.gan_weights_path, by_name=True)  # Try loading weights by name
            print("GAN weights loaded successfully.")
            return gan
        except Exception as e:
            print(f"Error loading GAN weights: {e}")
            return None

    def load_xgb_model(self):
        """Load the XGBoost model."""
        try:
            clf = joblib.load(self.xgb_model_path)
            print("XGBoost model loaded successfully.")
            return clf
        except Exception as e:
            print(f"Error loading XGBoost model: {e}")
            return None

    def gan_predict(self):
        gan = self.load_gan_model()
        if gan is None:
            print("Invalid GAN model.")
            return

        clf = self.load_xgb_model()
        if clf is None:
            print("Invalid XGBoost model.")
            return

        for sym, date, data in self.data:
            # Prepare data for GAN prediction
            data = np.expand_dims(data, axis=0)  # Adding batch dimension
            noise = tf.random.normal([1, 200])  # Assuming noise_dim is 200
            generated_features = gan.generator.predict(noise)
            generated_features = generated_features.flatten().reshape(1, -1)  # Flatten and reshape for XGBoost

            features = xgb.DMatrix(generated_features)

            # Predict using XGBoost model
            prediction = clf.predict(features)
            print(f'{str(date).split(" ")[0]} {sym} Prediction: {prediction[0]}')

# Example usage
predictor = Predict(num_historical_days=HISTORICAL_DAYS_AMOUNT, days=DAYS_AHEAD, pct_change=PCT_CHANGE_AMOUNT)
predictor.gan_predict()
# Out:
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AAL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AAON.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ACHC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ACM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ADC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AFG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AGCO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AIT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ALE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ALGM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ALLY.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ALTM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ALTR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ALV.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AMED.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AMG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AMH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AMKR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ANF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/APPF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ARMK.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ARW.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ARWR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ASB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ASGN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ASH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ATR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AVNT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AVT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AVTR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AXTA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AYI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AZPN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/AZTA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BCO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BDC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BERY.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BHF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BIO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BJ.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BKH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BLD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BLKB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BMRN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BRBR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BRKR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BRX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BURL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BWXT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/BYD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CACI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CADE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CAR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CASY.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CBSH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CBT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CCK.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CDP.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CELH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CFR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CGNX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CHDN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CHE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CHH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CHRD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CHX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CIEN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CIVI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CLF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CLH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CMC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CNH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CNM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CNO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CNX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CNXC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/COHR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/COKE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/COLB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/COLM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/COTY.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CPRI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CRI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CROX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CRUS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CSL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CUBE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CUZ.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CVLT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CW.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CXT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/CYTK.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/DAR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/DBX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/DCI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/DINO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/DKS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/DLB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/DOCS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/DOCU.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/DT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/DTM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/DUOL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/EEFT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/EGP.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/EHC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ELF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ELS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/EME.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ENOV.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ENS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ENSG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/EPR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/EQH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ESAB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ESNT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/EVR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/EWBC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/EXE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/EXEL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/EXLS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/EXP.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/EXPO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FAF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FBIN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FCFS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FCN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FFIN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FHI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FHN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FIVE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FIX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FLG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FLO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FLR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FLS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FNB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FND.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FNF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/FYBR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/G.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GAP.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GATX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GBCI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GEF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GGG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GHC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GLPI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GME.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GMED.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GNTX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GPK.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GTLS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/GXO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/H.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/HAE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/HALO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/HGV.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/HLI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/HLNE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/HOG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/HOMB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/HQY.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/HR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/HRB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/HWC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/HXL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/IBKR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/IBOC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/IDA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ILMN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/INGR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/IPGP.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/IRDM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/IRT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ITT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/JAZZ.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/JEF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/JHG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/JLL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/JWN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/KBH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/KBR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/KD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/KEX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/KMPR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/KNF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/KNSL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/KNX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/KRC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/KRG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LAD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LAMR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LANC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LEA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LECO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LFUS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LII.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LITE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LIVN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LNTH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LNW.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LOPE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LPX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LSCC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/LSTR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/M.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MAN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MANH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MASI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MAT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MEDP.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MIDD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MKSI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MMS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MORN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MSA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MSM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MTDR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MTG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MTN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MTSI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MTZ.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MUR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/MUSA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NBIX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NEOG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NEU.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NFG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NJR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NLY.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NNN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NOV.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NOVT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NSA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NSP.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NVST.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NVT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NWE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NXST.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NXT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/NYT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/OC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/OGE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/OGS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/OHI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/OLED.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/OLLI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/OLN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ONB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ONTO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/OPCH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ORA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ORI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/OSK.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/OVV.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/OZK.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PAG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PBF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PCH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PCTY.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PEN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PFGC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PII.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PK.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PLNT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PNFP.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/POR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/POST.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/POWI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PPC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PRGO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PRI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PSN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PSTG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/PVH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/QLYS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/R.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RBA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RBC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RCM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/REXR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RGA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RGEN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RGLD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RLI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RMBS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RNR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ROIV.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RPM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RRC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RRX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RYAN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/RYN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SAIA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SAIC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SAM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SBRA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SCI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SEIC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SFM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SHC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SIGI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SKX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SLAB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SLGN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SLM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SMG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SNV.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SNX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SON.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SRPT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SSB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SSD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ST.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/STAG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/STWD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SWX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/SYNA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TCBI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TDC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TEX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/THC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/THG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/THO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TKO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TKR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TMHC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TNL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TOL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TPL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TPX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TREX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TTC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TTEK.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TXNM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/TXRH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/UA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/UAA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/UBSI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/UFPI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/UGI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/UMBF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/UNM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/USFD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/UTHR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/VAC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/VAL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/VC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/VLY.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/VMI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/VNO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/VNOM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/VNT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/VOYA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/VSH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/VVV.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WAL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WBS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WCC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WEN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WEX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WFRD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WHR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WING.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WLK.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WMG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WMS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WPC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WSM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WSO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WTFC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WTRG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WTS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WU.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/WWD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/X.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/XPO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/XRAY.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/YETI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ZI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Optimized_S&P400_SameTime/stock_data/ZION.csv
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py:258: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# GAN weights loaded successfully.
# XGBoost model loaded successfully.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 ENOV.csv Prediction: [0.4943371  0.50566286]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2024-10-28 FHN.csv Prediction: [0.48656368 0.5134363 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2024-10-28 GHC.csv Prediction: [0.460912  0.5390881]
